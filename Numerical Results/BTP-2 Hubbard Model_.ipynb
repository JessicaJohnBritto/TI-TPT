# %% [markdown]
# # Installations and Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
from numpy import linalg as LA
import sympy as sp
from mpl_toolkits import mplot3d
import seaborn as sns
# import qutip
# %pylab inline
from ipywidgets import *
from matplotlib.pyplot import figure
plt.style.use('seaborn')
import tenpy
tenpy.show_config()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# tenpy 1.0.0 (compiled without HAVE_MKL),
# git revision unknown using
# python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# numpy 1.22.3, scipy 1.8.1

# %%
import numpy as np
import matplotlib.pyplot as plt

def partition_function(beta, U, t, mu):
    Z2 = 2 + np.exp(-beta * (U)) + np.exp(-beta*((U/2)-np.sqrt((U*U/4)+(4*t*t)))) + np.exp(-beta*((U/2)+np.sqrt((U*U/4)+(4*t*t))))
    print('Z2:')
    print(Z2)
    print('**************')
    return Z2

import numpy as np

def average_occupation_number(beta, U, t, mu):
    Z = partition_function(beta, U, t, mu)
    
    average =  np.exp(-beta * (U)) + (0.5-(0.25*U*np.sqrt(1/((U*U/4)+(4*t*t)))))*np.exp(-beta*((U/2)-np.sqrt((U*U/4)+(4*t*t)))) + (0.5+(0.25*U*np.sqrt(1/((U*U/4)+(4*t*t)))))*np.exp(-beta*((U/2)+np.sqrt((U*U/4)+(4*t*t))))
    print('average:')
    print(average)
    print('**************')
    average_occupation = average/Z
    print('average_occupation:')
    print(average_occupation)
    print('**************')
    return average_occupation

beta = 2.6531028*(10**20)  #1/(((273)*1.380649/(10**(-23))))
t = (1/16.5611910112)*1.602/(10**(19))
U_values = (1/16.5611910112)*1.602/(10**(19))*np.linspace(0, 2, 100) 

N2_average = []
for U in U_values:
    N2 = average_occupation_number(beta, U, t, mu=0.0)
    N2_average.append(N2)

print(N2_average)
plt.figure(figsize=(10, 6))
plt.plot(U_values/t, N2_average, label='Average Occupation Number vs U/t')
plt.xlabel('U/t')
plt.ylabel('Average Occupation Number')
plt.title('Average Occupation Number vs U/t')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Z2:
# 172.49828504694744
# **************
# average:
# 85.74914252347372
# **************
# average_occupation:
# 0.4971014204583894
# **************
# Z2:
# 168.12108458030752
# **************
# average:
# 83.11821389580295
# **************
# average_occupation:
# 0.49439494221261293
# **************
# Z2:
# 163.87795337336
# **************
# average:
# 80.57681331240492
# **************
# average_occupation:
# 0.49168794004174754
# **************
# Z2:
# 159.76433522570315
# **************
# average:
# 78.12166339044566
# **************
# average_occupation:
# 0.48898061810904914
# **************
# Z2:
# 155.77584054988606
# **************
# average:
# 75.74961348479057
# **************
# average_occupation:
# 0.4862731808565162
# **************
# Z2:
# 151.9082399340216
# **************
# average:
# 73.45763457356627
# **************
# average_occupation:
# 0.4835658329361934
# **************
# Z2:
# 148.15745796399338
# **************
# average:
# 71.24281435723162
# ...
